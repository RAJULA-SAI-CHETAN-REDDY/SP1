# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

img = cv.imread("egfile/robotred.png",256)
img2 = cv.imread("egfile/robotred.png",256)
# cv.imshow('name',img)
# cv.waitKey(1000)

img.shape
# Out:
# (1062, 1263, 3)

# %%
plt.imshow(img)
plt.show()

# %%
scale_factor = 0.3
new_img = cv.resize(img, None, fx = scale_factor, fy = scale_factor, interpolation = cv.INTER_AREA)
plt.imshow(new_img)
plt.show()

# %%
print(new_img.shape)
# Out:
# (319, 379, 3)

# %%
robo = new_img[ 0:300, 100:270]
img[650:950, 60:230] = robo
img[650:950, 930:1100] = robo

# %%
plt.imshow(img)
plt.show()

# %%
robo_red = cv.cvtColor(robo,cv.COLOR_BGR2RGB)
robo_gray = cv.cvtColor(robo_red,cv.COLOR_RGB2GRAY)
robo_gray3 = cv.cvtColor(robo_gray,cv.COLOR_GRAY2BGR)
img2[650:950, 60:230] = robo_gray3
img2[650:950, 930:1100] = robo_red

# %%
plt.imshow(img2)
plt.show()
